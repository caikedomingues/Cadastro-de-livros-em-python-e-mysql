# %% [markdown]
# Inicio do sistema: Essa parte deve ser executada antes de qualquer outra ação.

# %%
import pymysql

conexao = pymysql.connect(
    
    host = 'localhost',
    
    user = 'root',
    
    password = '',
    
    database = 'livraria'
)

banco = conexao.cursor()

# %% [markdown]
#                                                 Parte do Sistema Para Clientes

# %% [markdown]
# Cadastro de Clientes

# %% [markdown]
#                                                  Parte do Sistema Para Funcionários
