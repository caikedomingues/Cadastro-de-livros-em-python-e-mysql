# %% [markdown]
# Criando a conexão com o mysql

# %%
import pymysql

conexao = pymysql.connect(
    
    host = 'localhost',
    
    user = 'root',
    
    password = ''
    
    database = 'livraria'
)

banco = conexao.cursor()
